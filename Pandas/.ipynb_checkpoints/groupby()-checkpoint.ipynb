# %% [markdown]
# ### groupby()
# **1.** Used for Reshaping and Aggregation.
#
# **2.** Returns a **DataFrameGroupBy** object.
#
# **3.** Follows Three step process.
# > 1. Splitting the data into groups.
# 2. Applying a function to each group independently,
# 3. Combining the results into a data structure.
#
# **4.** During `Apply` process, we can apply one of the below three :
# > 1. **Aggregation:** performs a statistical summary on each grouup. Takes single func or list of func
#
# >2. **Transformation:**  `transform()`Perfroms a provided function on a single column or series of the grouped dataframe. Returns dataframe of same length as the parent.
#
# >3. **Filtration:** `filter()` Filter a dataframe based on a given criteria or function. produces a sub dataframe.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Dataset/volcano_data_2010.csv', usecols= ['Name', 'Country', 'Year', 'Location', 'Type'])
df
# Out:
#     Year                    Name              Location           Country  \
# 0   2010              Tungurahua               Ecuador           Ecuador
# 1   2010        Eyjafjallajokull             Iceland-S           Iceland
# 2   2010                  Pacaya             Guatemala         Guatemala
# 3   2010                 Sarigan  Mariana Is-C Pacific     United States
# 4   2010  Karangetang [Api Siau]  Sangihe Is-Indonesia         Indonesia
# ..   ...                     ...                   ...               ...
# 58  2018                 Kilauea           Hawaiian Is     United States
# 59  2018                 Kadovar      New Guinea-NE of  Papua New Guinea
# 60  2018                    Ijen                  Java         Indonesia
# 61  2018                 Kilauea           Hawaiian Is     United States
# 62  2018                    Aoba    Vanuatu-SW Pacific           Vanuatu
#
#                Type
# 0     Stratovolcano
# 1     Stratovolcano
# 2   Complex volcano
# 3     Stratovolcano
# 4     Stratovolcano
# ..              ...
# 58   Shield volcano
# 59    Stratovolcano
# 60    Stratovolcano
# 61   Shield volcano
# 62   Shield volcano
#
# [63 rows x 5 columns]

# %%
type(df.groupby('Type'))
# It shows thetype of the groupby object
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df.groupby('Type').apply(display)
# Out:
#     Year           Name      Location        Country     Type
# 44  2016    Yellowstone    US-Wyoming  United States  Caldera
# 46  2016            Aso  Kyushu-Japan          Japan  Caldera
# 51  2017  Campi Flegrei         Italy          Italy  Caldera
#     Year                Name      Location    Country             Type
# 2   2010              Pacaya     Guatemala  Guatemala  Complex volcano
# 32  2014             On-take  Honshu-Japan      Japan  Complex volcano
# 50  2017  Dieng Volc Complex          Java  Indonesia  Complex volcano
#     Year      Name     Location      Country       Type
# 29  2013  Okataina  New Zealand  New Zealand  Lava dome
# 41  2015  Okataina  New Zealand  New Zealand  Lava dome
#     Year       Name            Location        Country            Type
# 10  2011  Kirishima        Kyushu-Japan          Japan  Shield volcano
# 19  2012    Kilauea         Hawaiian Is  United States  Shield volcano
# 20  2012    Kilauea         Hawaiian Is  United States  Shield volcano
# 21  2012  Tolbachik           Kamchatka         Russia  Shield volcano
# 33  2014    Kilauea         Hawaiian Is  United States  Shield volcano
# 52  2017       Aoba  Vanuatu-SW Pacific        Vanuatu  Shield volcano
# 58  2018    Kilauea         Hawaiian Is  United States  Shield volcano
# 61  2018    Kilauea         Hawaiian Is  United States  Shield volcano
# 62  2018       Aoba  Vanuatu-SW Pacific        Vanuatu  Shield volcano
#     Year                    Name              Location           Country  \
# 0   2010              Tungurahua               Ecuador           Ecuador
# 1   2010        Eyjafjallajokull             Iceland-S           Iceland
# 3   2010                 Sarigan  Mariana Is-C Pacific     United States
# 4   2010  Karangetang [Api Siau]  Sangihe Is-Indonesia         Indonesia
# 5   2010                Sinabung               Sumatra         Indonesia
# 6   2010                  Merapi                  Java         Indonesia
# 7   2010              Tungurahua               Ecuador           Ecuador
# 8   2010         Tengger Caldera                  Java         Indonesia
# 9   2011                  Merapi                  Java         Indonesia
# 11  2011                 Bulusan     Luzon-Philippines       Philippines
# 12  2011  Karangetang [Api Siau]  Sangihe Is-Indonesia         Indonesia
# 13  2011              Tungurahua               Ecuador           Ecuador
# 14  2011                 Puyehue               Chile-C             Chile
# 15  2011                   Nabro             Africa-NE           Eritrea
# 17  2011            Lokon-Empung    Sulawesi-Indonesia         Indonesia
# 18  2011                Gamalama   Halmahera-Indonesia         Indonesia
# 22  2013                  Merapi                  Java         Indonesia
# 23  2013                 Paluweh       Lesser Sunda Is         Indonesia
# 24  2013                   Mayon     Luzon-Philippines       Philippines
# 25  2013                 Paluweh       Lesser Sunda Is         Indonesia
# 26  2013                  Ubinas                  Peru              Peru
# 27  2013             Sakura-jima          Kyushu-Japan             Japan
# 28  2013                Sinabung               Sumatra         Indonesia
# 30  2014                Sinabung               Sumatra         Indonesia
# 31  2014                   Kelut                  Java         Indonesia
# 34  2014                    Fogo         Cape Verde Is        Cape Verde
# 35  2014                Gamalama   Halmahera-Indonesia         Indonesia
# 36  2015                Sinabung               Sumatra         Indonesia
# 37  2015                 Calbuco               Chile-S             Chile
# 38  2015  Karangetang [Api Siau]  Sangihe Is-Indonesia         Indonesia
# 39  2015                   Manam      New Guinea-NE of  Papua New Guinea
# 40  2015                Sinabung               Sumatra         Indonesia
# 42  2016                Sinabung               Sumatra         Indonesia
# 43  2016                Sinabung               Sumatra         Indonesia
# 45  2016                 Rinjani       Lesser Sunda Is         Indonesia
# 47  2017                    Etna                 Italy             Italy
# 48  2017                Sinabung               Sumatra         Indonesia
# 49  2017                   Fuego             Guatemala         Guatemala
# 53  2017                  Merapi                  Java         Indonesia
# 54  2017                Sinabung               Sumatra         Indonesia
# 55  2018                 Kadovar      New Guinea-NE of  Papua New Guinea
# 56  2018                   Mayon     Luzon-Philippines       Philippines
# 57  2018         Kusatsu-Shirane          Honshu-Japan             Japan
# 59  2018                 Kadovar      New Guinea-NE of  Papua New Guinea
# 60  2018                    Ijen                  Java         Indonesia
#
#              Type
# 0   Stratovolcano
# 1   Stratovolcano
# 3   Stratovolcano
# 4   Stratovolcano
# 5   Stratovolcano
# 6   Stratovolcano
# 7   Stratovolcano
# 8   Stratovolcano
# 9   Stratovolcano
# 11  Stratovolcano
# 12  Stratovolcano
# 13  Stratovolcano
# 14  Stratovolcano
# 15  Stratovolcano
# 17  Stratovolcano
# 18  Stratovolcano
# 22  Stratovolcano
# 23  Stratovolcano
# 24  Stratovolcano
# 25  Stratovolcano
# 26  Stratovolcano
# 27  Stratovolcano
# 28  Stratovolcano
# 30  Stratovolcano
# 31  Stratovolcano
# 34  Stratovolcano
# 35  Stratovolcano
# 36  Stratovolcano
# 37  Stratovolcano
# 38  Stratovolcano
# 39  Stratovolcano
# 40  Stratovolcano
# 42  Stratovolcano
# 43  Stratovolcano
# 45  Stratovolcano
# 47  Stratovolcano
# 48  Stratovolcano
# 49  Stratovolcano
# 53  Stratovolcano
# 54  Stratovolcano
# 55  Stratovolcano
# 56  Stratovolcano
# 57  Stratovolcano
# 59  Stratovolcano
# 60  Stratovolcano
#     Year   Name   Location  Country                Type
# 16  2011  Katla  Iceland-S  Iceland  Subglacial volcano
# Empty DataFrame
# Columns: []
# Index: []

# %%
# We can see the no. of groups the object have
df.groupby('Type')

# %%
# Size of each group
df.groupby('Type').size()
# Out:
# Type
# Caldera                3
# Complex volcano        3
# Lava dome              2
# Shield volcano         9
# Stratovolcano         45
# Subglacial volcano     1
# dtype: int64

# %%
# All the groups at once
dict_ = df.groupby('Type').groups
dict_
# Out:
# {'Caldera': [44, 46, 51], 'Complex volcano': [2, 32, 50], 'Lava dome': [29, 41], 'Shield volcano': [10, 19, 20, 21, 33, 52, 58, 61, 62], 'Stratovolcano': [0, 1, 3, 4, 5, 6, 7, 8, 9, 11, 12, 13, 14, 15, 17, 18, 22, 23, 24, 25, 26, 27, 28, 30, 31, 34, 35, 36, 37, 38, 39, 40, 42, 43, 45, 47, 48, 49, 53, 54, 55, 56, 57, 59, 60], 'Subglacial volcano': [16]}

# %%
for items in dict_.keys():
    print(items)
# Out:
# Caldera
# Complex volcano
# Lava dome
# Shield volcano
# Stratovolcano
# Subglacial volcano

# %%
# Getting a particualr group 
df.groupby('Type').get_group('Complex volcano')
# Out:
#     Year                Name      Location    Country             Type
# 2   2010              Pacaya     Guatemala  Guatemala  Complex volcano
# 32  2014             On-take  Honshu-Japan      Japan  Complex volcano
# 50  2017  Dieng Volc Complex          Java  Indonesia  Complex volcano

# %%
# First rows of each group (oppo is last()) 
df.groupby('Type').first()
# Out:
#                     Year         Name      Location        Country
# Type
# Caldera             2016  Yellowstone    US-Wyoming  United States
# Complex volcano     2010       Pacaya     Guatemala      Guatemala
# Lava dome           2013     Okataina   New Zealand    New Zealand
# Shield volcano      2011    Kirishima  Kyushu-Japan          Japan
# Stratovolcano       2010   Tungurahua       Ecuador        Ecuador
# Subglacial volcano  2011        Katla     Iceland-S        Iceland

# %% [markdown]
# ### aggregation

# %%
df.groupby('Type')['Year'].agg('count') 
# simmilar to df.groupby('Type')['Year'].count()
# Out:
# Type
# Caldera                3
# Complex volcano        3
# Lava dome              2
# Shield volcano         9
# Stratovolcano         45
# Subglacial volcano     1
# Name: Year, dtype: int64

# %% [markdown]
# In between 2010-2018, Volcano type of strto has shown highest no of eruptions.

# %%
df.groupby('Year')['Country'].count()
# Out:
# Year
# 2010     9
# 2011    10
# 2012     3
# 2013     8
# 2014     6
# 2015     6
# 2016     5
# 2017     8
# 2018     8
# Name: Country, dtype: int64

# %%
# Without Columns
df.groupby(['Type','Country']).agg('count')
# Out:
#                                      Year  Name  Location
# Type               Country
# Caldera            Italy                1     1         1
#                    Japan                1     1         1
#                    United States        1     1         1
# Complex volcano    Guatemala            1     1         1
#                    Indonesia            1     1         1
#                    Japan                1     1         1
# Lava dome          New Zealand          2     2         2
# Shield volcano     Japan                1     1         1
#                    Russia               1     1         1
#                    United States        5     5         5
#                    Vanuatu              2     2         2
# Stratovolcano      Cape Verde           1     1         1
#                    Chile                2     2         2
#                    Ecuador              3     3         3
#                    Eritrea              1     1         1
#                    Guatemala            1     1         1
#                    Iceland              1     1         1
#                    Indonesia           25    25        25
#                    Italy                1     1         1
#                    Japan                2     2         2
#                    Papua New Guinea     3     3         3
#                    Peru                 1     1         1
#                    Philippines          3     3         3
#                    United States        1     1         1
# Subglacial volcano Iceland              1     1         1

# %%
# Using a custom agg func
# return True if total no of eruption equals and more than 3, else False
def cnt(val):
    if val >= 3:
        return True
    else: return False

df.groupby('Country')['Location'].agg('count').agg(cnt)
# Out:
# Country
# Cape Verde          False
# Chile               False
# Ecuador              True
# Eritrea             False
# Guatemala           False
# Iceland             False
# Indonesia            True
# Italy               False
# Japan                True
# New Zealand         False
# Papua New Guinea     True
# Peru                False
# Philippines          True
# Russia              False
# United States        True
# Vanuatu             False
# Name: Location, dtype: bool

# %%
# lambda equivalent of above func
df.groupby('Country')['Location'].agg('count').agg(lambda val: True if val >= 3 else False)
# Out:
# Country
# Cape Verde          False
# Chile               False
# Ecuador              True
# Eritrea             False
# Guatemala           False
# Iceland             False
# Indonesia            True
# Italy               False
# Japan                True
# New Zealand         False
# Papua New Guinea     True
# Peru                False
# Philippines          True
# Russia              False
# United States        True
# Vanuatu             False
# Name: Location, dtype: bool

# %% [markdown]
# out of 8 years, 2011 saw highest no of eruption.

# %%
# we can set custom column name too
df.groupby('Country')['Location'].agg(Tot_Ocuurence =('count'))
# Out:
#                   Tot_Ocuurence
# Country
# Cape Verde                    1
# Chile                         2
# Ecuador                       3
# Eritrea                       1
# Guatemala                     2
# Iceland                       2
# Indonesia                    26
# Italy                         2
# Japan                         5
# New Zealand                   2
# Papua New Guinea              3
# Peru                          1
# Philippines                   3
# Russia                        1
# United States                 7
# Vanuatu                       2

# %% [markdown]
# Indonesia saw highest no of eruptions.

# %%
# Per year, Per Country no of eruptions. 
df.groupby('Year')['Country'].value_counts()
# Out:
# Year  Country
# 2010  Indonesia           4
#       Ecuador             2
#       Guatemala           1
#       Iceland             1
#       United States       1
# 2011  Indonesia           4
#       Chile               1
#       Ecuador             1
#       Eritrea             1
#       Iceland             1
#       Japan               1
#       Philippines         1
# 2012  United States       2
#       Russia              1
# 2013  Indonesia           4
#       Japan               1
#       New Zealand         1
#       Peru                1
#       Philippines         1
# 2014  Indonesia           3
#       Cape Verde          1
#       Japan               1
#       United States       1
# 2015  Indonesia           3
#       Chile               1
#       New Zealand         1
#       Papua New Guinea    1
# 2016  Indonesia           3
#       Japan               1
#       United States       1
# 2017  Indonesia           4
#       Italy               2
#       Guatemala           1
#       Vanuatu             1
# 2018  Papua New Guinea    2
#       United States       2
#       Indonesia           1
#       Japan               1
#       Philippines         1
#       Vanuatu             1
# Name: Country, dtype: int64

# %% [markdown]
# #### transformation. see transform() notebook

# %% [markdown]
# #### filtration
#
# Evalutes to True or False

# %%
# printing data of total no of eruption equals and more than 3
df.groupby('Country').filter(lambda val : len(val)>=3)
# Out:
#     Year                    Name              Location           Country  \
# 0   2010              Tungurahua               Ecuador           Ecuador
# 3   2010                 Sarigan  Mariana Is-C Pacific     United States
# 4   2010  Karangetang [Api Siau]  Sangihe Is-Indonesia         Indonesia
# 5   2010                Sinabung               Sumatra         Indonesia
# 6   2010                  Merapi                  Java         Indonesia
# 7   2010              Tungurahua               Ecuador           Ecuador
# 8   2010         Tengger Caldera                  Java         Indonesia
# 9   2011                  Merapi                  Java         Indonesia
# 10  2011               Kirishima          Kyushu-Japan             Japan
# 11  2011                 Bulusan     Luzon-Philippines       Philippines
# 12  2011  Karangetang [Api Siau]  Sangihe Is-Indonesia         Indonesia
# 13  2011              Tungurahua               Ecuador           Ecuador
# 17  2011            Lokon-Empung    Sulawesi-Indonesia         Indonesia
# 18  2011                Gamalama   Halmahera-Indonesia         Indonesia
# 19  2012                 Kilauea           Hawaiian Is     United States
# 20  2012                 Kilauea           Hawaiian Is     United States
# 22  2013                  Merapi                  Java         Indonesia
# 23  2013                 Paluweh       Lesser Sunda Is         Indonesia
# 24  2013                   Mayon     Luzon-Philippines       Philippines
# 25  2013                 Paluweh       Lesser Sunda Is         Indonesia
# 27  2013             Sakura-jima          Kyushu-Japan             Japan
# 28  2013                Sinabung               Sumatra         Indonesia
# 30  2014                Sinabung               Sumatra         Indonesia
# 31  2014                   Kelut                  Java         Indonesia
# 32  2014                 On-take          Honshu-Japan             Japan
# 33  2014                 Kilauea           Hawaiian Is     United States
# 35  2014                Gamalama   Halmahera-Indonesia         Indonesia
# 36  2015                Sinabung               Sumatra         Indonesia
# 38  2015  Karangetang [Api Siau]  Sangihe Is-Indonesia         Indonesia
# 39  2015                   Manam      New Guinea-NE of  Papua New Guinea
# 40  2015                Sinabung               Sumatra         Indonesia
# 42  2016                Sinabung               Sumatra         Indonesia
# 43  2016                Sinabung               Sumatra         Indonesia
# 44  2016             Yellowstone            US-Wyoming     United States
# 45  2016                 Rinjani       Lesser Sunda Is         Indonesia
# 46  2016                     Aso          Kyushu-Japan             Japan
# 48  2017                Sinabung               Sumatra         Indonesia
# 50  2017      Dieng Volc Complex                  Java         Indonesia
# 53  2017                  Merapi                  Java         Indonesia
# 54  2017                Sinabung               Sumatra         Indonesia
# 55  2018                 Kadovar      New Guinea-NE of  Papua New Guinea
# 56  2018                   Mayon     Luzon-Philippines       Philippines
# 57  2018         Kusatsu-Shirane          Honshu-Japan             Japan
# 58  2018                 Kilauea           Hawaiian Is     United States
# 59  2018                 Kadovar      New Guinea-NE of  Papua New Guinea
# 60  2018                    Ijen                  Java         Indonesia
# 61  2018                 Kilauea           Hawaiian Is     United States
#
#                Type
# 0     Stratovolcano
# 3     Stratovolcano
# 4     Stratovolcano
# 5     Stratovolcano
# 6     Stratovolcano
# 7     Stratovolcano
# 8     Stratovolcano
# 9     Stratovolcano
# 10   Shield volcano
# 11    Stratovolcano
# 12    Stratovolcano
# 13    Stratovolcano
# 17    Stratovolcano
# 18    Stratovolcano
# 19   Shield volcano
# 20   Shield volcano
# 22    Stratovolcano
# 23    Stratovolcano
# 24    Stratovolcano
# 25    Stratovolcano
# 27    Stratovolcano
# 28    Stratovolcano
# 30    Stratovolcano
# 31    Stratovolcano
# 32  Complex volcano
# 33   Shield volcano
# 35    Stratovolcano
# 36    Stratovolcano
# 38    Stratovolcano
# 39    Stratovolcano
# 40    Stratovolcano
# 42    Stratovolcano
# 43    Stratovolcano
# 44          Caldera
# 45    Stratovolcano
# 46          Caldera
# 48    Stratovolcano
# 50  Complex volcano
# 53    Stratovolcano
# 54    Stratovolcano
# 55    Stratovolcano
# 56    Stratovolcano
# 57    Stratovolcano
# 58   Shield volcano
# 59    Stratovolcano
# 60    Stratovolcano
# 61   Shield volcano

# %%
# handling missing values
temp_df = pd.DataFrame({
    'name': ['A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'],
    'B': [np.nan, 4, np.nan, 5,6,np.nan, 8,2]
})
temp_df
# Out:
#   name    B
# 0    A  NaN
# 1    A  4.0
# 2    B  NaN
# 3    B  5.0
# 4    B  6.0
# 5    C  NaN
# 6    C  8.0
# 7    C  2.0

# %%
# By defualt, groupby() ignores the nan values while appling an aggregated function
# becoz of defualt 'dropna = True' argument
temp_df.groupby('name').mean()
# Out:
#         B
# name
# A     4.0
# B     5.5
# C     5.0

# %%
# replacing all nan values with mean values
temp_df['B'] = temp_df.groupby('name')['B'].transform( lambda val: val.fillna(np.mean(val)))
temp_df
# Out:
#   name    B
# 0    A  4.0
# 1    A  4.0
# 2    B  5.5
# 3    B  5.0
# 4    B  6.0
# 5    C  5.0
# 6    C  8.0
# 7    C  2.0
