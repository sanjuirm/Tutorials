# %% [markdown]
#  **IMP:** `transform` works on just one Series at a time and `apply` works on the entire DataFrame at once. Keep in mind during applying `groupby()` method.
#
# Follow the link for best understanding : https://stackoverflow.com/questions/13854476/pandas-transform-doesnt-work-sorting-groupby-output/13854901#13854901

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(  {   'A': [5,6,7],
                        'B': [8,9,10]}) 

df1 = pd.read_csv(r"C:\Users\sanju\OneDrive\Desktop\Tutorials\Pandas\Dataset\weather.csv", usecols= ['temperature',	'humidity'])

df2 = pd.DataFrame({
    'key': ['a','b','c'] * 4,
    'A': np.arange(12),
    'B': [1,2,3] * 4,
})
display(df, df1, df2.head())
# Out:
#    A   B
# 0  5   8
# 1  6   9
# 2  7  10
#    temperature  humidity
# 0           65        56
# 1           61        54
# 2           70        60
# 3           30        50
# 4           28        52
# 5           25        51
#   key  A  B
# 0   a  0  1
# 1   b  1  2
# 2   c  2  3
# 3   a  3  1
# 4   b  4  2

# %% [markdown]
# **1.** `apply(func, axis= 0)` it applies the function `func` along the given axis(series) (rows for 1, columns for 0) of the DataFrame. Returns a pandas Series or DataFrame.
#
# **2.** `transform(func, axis= 0)` it applies the function `func` along the given axis. Returns a DataFrame which must have same axis length as the original DataFrame.

# %%
# Using apply() method to manipulate dataframe

def add( x ):
    return x+10

display(df.apply( add ))  # Sums along the row of the dataframe 
# Equivalent to display(df.apply( lambda n : n + 10))
# Out:
#     A   B
# 0  15  18
# 1  16  19
# 2  17  20

# %%
# Using transform() method to manipulate dataframe
def add( x ):
    return x+10

display(df.transform( add ) ) # Sums along the row of the dataframe 
# Equivalent to display(df.transform( lambda n : n + 10))
# Out:
#     A   B
# 0  15  18
# 1  16  19
# 2  17  20

# %%
# Using apply() method to manipulate a Series
display(df['B'].apply( lambda n : n + 15 ))
# Out:
# 0    23
# 1    24
# 2    25
# Name: B, dtype: int64

# %%
# Using apply() method to work with each Series separately
df.apply(lambda n : n['A']*2 * n['B']*5, axis= 1)
# Out:
# 0    400
# 1    540
# 2    700
# dtype: int64

# %%
# Using transform() method to manipulate a Series
display(df['A'].transform( lambda n : n + 15 ))
# Out:
# 0    20
# 1    21
# 2    22
# Name: A, dtype: int64

# %%
# Using transform() method to work with each Series separately. will Produce an ERROR.
df.transform(lambda n : n['A']*2 * n['B']*5, axis= 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# sanjuirm\Tutorials\Pandas\transform(), apply().ipynb Cell 8 in <cell line: 2>()
#       <a href='vscode-notebook-cell://github/sanjuirm/Tutorials/Pandas/transform%28%29%2C%20apply%28%29.ipynb#ch0000007vscode-vfs?line=0'>1</a> # Using transform() method to work with each Series separately. will Produce an ERROR.
# ----> <a href='vscode-notebook-cell://github/sanjuirm/Tutorials/Pandas/transform%28%29%2C%20apply%28%29.ipynb#ch0000007vscode-vfs?line=1'>2</a> df.transform(lambda n : n['A']*2 * n['B']*5, axis= 1)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:8672, in DataFrame.transform(self, func, axis, *args, **kwargs)
#    8669 from pandas.core.apply import frame_apply
#    8671 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# -> 8672 result = op.transform()
#    8673 assert isinstance(result, DataFrame)
#    8674 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\apply.py:206, in Apply.transform(self)
#     204 if obj._get_axis_number(axis) == 1:
#     205     assert not is_series
# --> 206     return obj.T.transform(func, 0, *args, **kwargs).T
#     208 if is_list_like(func) and not is_dict_like(func):
#     209     func = cast(List[AggFuncTypeBase], func)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:8672, in DataFrame.transform(self, func, axis, *args, **kwargs)
#    8669 from pandas.core.apply import frame_apply
#    8671 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# -> 8672 result = op.transform()
#    8673 assert isinstance(result, DataFrame)
#    8674 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\apply.py:240, in Apply.transform(self)
#     236     raise ValueError("Transform function failed")
#     237 if not isinstance(result, (ABCSeries, ABCDataFrame)) or not result.index.equals(
#     238     obj.index
#     239 ):
# --> 240     raise ValueError("Function did not transform")
#     242 return result
#
# ValueError: Function did not transform

# %% [markdown]
# **3.** Using transform() methods

# %%
# using a single fucntion
display(df.transform( func= ['exp']))   # Remember the resulting df must have same AXIS length as the original df
display(df1.transform( 'sqrt', axis= 1))

# Using a list of function
display(df1.transform( func= ['exp','sqrt'], axis=0))  # Generates a MultiIndex column DataFrame, have same axis (row) length as original 
display(df.transform(['exp','sqrt'], axis=1))          # Generates a MultiIndex DataFrame, have same axis (column) length as original
# Out:
#              A             B
#            exp           exp
# 0   148.413159   2980.957987
# 1   403.428793   8103.083928
# 2  1096.633158  22026.465795
#    temperature  humidity
# 0     8.062258  7.483315
# 1     7.810250  7.348469
# 2     8.366600  7.745967
# 3     5.477226  7.071068
# 4     5.291503  7.211103
# 5     5.000000  7.141428
#     temperature                humidity
#             exp      sqrt           exp      sqrt
# 0  1.694889e+28  8.062258  2.091659e+24  7.483315
# 1  3.104298e+26  7.810250  2.830753e+23  7.348469
# 2  2.515439e+30  8.366600  1.142007e+26  7.745967
# 3  1.068647e+13  5.477226  5.184706e+21  7.071068
# 4  1.446257e+12  5.291503  3.831008e+22  7.211103
# 5  7.200490e+10  5.000000  1.409349e+22  7.141428
#                   A             B
# 0 exp    148.413159   2980.957987
#   sqrt     2.236068      2.828427
# 1 exp    403.428793   8103.083928
#   sqrt     2.449490      3.000000
# 2 exp   1096.633158  22026.465795
#   sqrt     2.645751      3.162278

# %%
# Using Dictionary to pass function
df1.transform({'temperature' : 'sqrt'}, axis=0)
# Out:
#    temperature
# 0     8.062258
# 1     7.810250
# 2     8.366600
# 3     5.477226
# 4     5.291503
# 5     5.000000

# %%
df2
# Out:
#    key   A  B
# 0    a   0  1
# 1    b   1  2
# 2    c   2  3
# 3    a   3  1
# 4    b   4  2
# 5    c   5  3
# 6    a   6  1
# 7    b   7  2
# 8    c   8  3
# 9    a   9  1
# 10   b  10  2
# 11   c  11  3

# %%
# groupby() method, mostly used 
df2.groupby('key').transform(sum) # Here sum() method is working, as it produces same axis length as parent
# Out:
#      A   B
# 0   18   4
# 1   22   8
# 2   26  12
# 3   18   4
# 4   22   8
# 5   26  12
# 6   18   4
# 7   22   8
# 8   26  12
# 9   18   4
# 10  22   8
# 11  26  12

# %%
df2.groupby('key')['A'].transform(sum)
# Out:
# 0     18
# 1     22
# 2     26
# 3     18
# 4     22
# 5     26
# 6     18
# 7     22
# 8     26
# 9     18
# 10    22
# 11    26
# Name: A, dtype: int32

# %%
# Can also be used to filter data
temp_df = pd.DataFrame({
  'restaurant_id': [101,102,103,104,105,106,107],
  'address': ['A','B','C','D', 'E', 'F', 'G'],
  'city': ['London','London','London','Oxford','Oxford', 'Durham', 'Durham'],
  'sales': [10,500,48,12,21,22,14]
})

temp_df[temp_df.groupby('city')['sales'].transform(sum) > 50]
# Out:
#    restaurant_id address    city  sales
# 0            101       A  London     10
# 1            102       B  London    500
# 2            103       C  London     48

# %%
temp_df.groupby('city').get_group('Oxford')   # Using get_group() method to select a group from groupby object
# Out:
#    restaurant_id address    city  sales
# 3            104       D  Oxford     12
# 4            105       E  Oxford     21

# %%
# Can handle missing values

temp_df = pd.DataFrame({
    'name': ['A', 'A', 'B', 'B', 'B', 'C', 'C', 'C'],
    'B': [np.nan, 4, np.nan, 5,6,np.nan, 8,2]
})
temp_df
# Out:
#   name    B
# 0    A  NaN
# 1    A  4.0
# 2    B  NaN
# 3    B  5.0
# 4    B  6.0
# 5    C  NaN
# 6    C  8.0
# 7    C  2.0

# %%
temp_df.fillna(temp_df['B'].mean())
# Out:
#   name    B
# 0    A  5.0
# 1    A  4.0
# 2    B  5.0
# 3    B  5.0
# 4    B  6.0
# 5    C  5.0
# 6    C  8.0
# 7    C  2.0

# %%
temp_df['B'] = temp_df.groupby('name')['B'].transform( lambda x: x.fillna(x.mean()))
temp_df
# Out:
#   name    B
# 0    A  4.0
# 1    A  4.0
# 2    B  5.5
# 3    B  5.0
# 4    B  6.0
# 5    C  5.0
# 6    C  8.0
# 7    C  2.0

# %% [markdown]
# **4.** Using apply() Method

# %%
df1.apply(['sum'], axis=0)  # Same as above, using a single function. Wrapping [] around fucntion produces a df otherwise a Series 
# equivalent to df1.apply(lambda n : [n.sum()])
# Out:
#      temperature  humidity
# sum          279       323

# %%
#  For groupby() method with apply(), it returns one value for each group(a,b,c) and the output shape is (num_of_groups, 1) .
df2.groupby('key').apply('sum')
# Out:
#       A   B
# key
# a    18   4
# b    22   8
# c    26  12

# %%
df2.groupby('key')['B'].apply('sum')
# Out:
# key
# a     4
# b     8
# c    12
# Name: B, dtype: int64

# %%
# We cannot get an aggregated result like sum or count using transform() method
# Becoz it would violate the cond. that the resulting df should have same
# Axis length as the original df.

df1.transform('count', axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# sanjuirm\Tutorials\Pandas\transform(), apply().ipynb Cell 19 in <cell line: 5>()
#       <a href='vscode-notebook-cell://github/sanjuirm/Tutorials/Pandas/transform%28%29%2C%20apply%28%29.ipynb#ch0000021vscode-vfs?line=0'>1</a> # We cannot get an aggregated result like sum or count using transform() method
#       <a href='vscode-notebook-cell://github/sanjuirm/Tutorials/Pandas/transform%28%29%2C%20apply%28%29.ipynb#ch0000021vscode-vfs?line=1'>2</a> # Becoz it would violate the cond. that the resulting df should have same
#       <a href='vscode-notebook-cell://github/sanjuirm/Tutorials/Pandas/transform%28%29%2C%20apply%28%29.ipynb#ch0000021vscode-vfs?line=2'>3</a> # Axis length as the original df.
# ----> <a href='vscode-notebook-cell://github/sanjuirm/Tutorials/Pandas/transform%28%29%2C%20apply%28%29.ipynb#ch0000021vscode-vfs?line=4'>5</a> df1.transform('count', axis=0)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:8672, in DataFrame.transform(self, func, axis, *args, **kwargs)
#    8669 from pandas.core.apply import frame_apply
#    8671 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# -> 8672 result = op.transform()
#    8673 assert isinstance(result, DataFrame)
#    8674 return result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\apply.py:240, in Apply.transform(self)
#     236     raise ValueError("Transform function failed")
#     237 if not isinstance(result, (ABCSeries, ABCDataFrame)) or not result.index.equals(
#     238     obj.index
#     239 ):
# --> 240     raise ValueError("Function did not transform")
#     242 return result
#
# ValueError: Function did not transform
